# %% [markdown]
# ## Anchored Diffusion Inference Notebook
# Use this notebook to load a trained ADLM checkpoint and generate text samples or compute evaluation metrics on a few samples
#
# ### Prerequisites
# - The working directory is set to the repository root.
# - A trained checkpoint is available on disk.
#
# Adjust the parameters in the next cell to point to your checkpoint and sampling configuration.

# %%
from pathlib import Path
import os

# --- User configuration ----------------------------------------------------
# Resolve repository root either from ADLM_PROJECT_ROOT or by walking up from the current directory.
ENV_ROOT = os.environ.get('ADLM_PROJECT_ROOT')
start_path = Path(ENV_ROOT).expanduser().resolve() if ENV_ROOT else Path.cwd().resolve()
def find_repo_root(path: Path) -> Path:
    for candidate in [path, *path.parents]:
        if (candidate / 'configs').is_dir():
            return candidate
    raise FileNotFoundError(
        f'Could not locate a Hydra config directory starting from {path}. '
        'Set ADLM_PROJECT_ROOT or edit PROJECT_ROOT above.'
)
PROJECT_ROOT = find_repo_root(start_path)
CONFIG_DIR = PROJECT_ROOT / 'configs'
CHECKPOINT_PATH = PROJECT_ROOT / 'ckpts/adlm-large.ckpt'
# Supported checkpoints: adlm-medium.ckpt (262B tokens), adlm-large.ckpt (524B tokens)
NUM_SAMPLE_BATCHES = 10  # Number of batches to sample in this notebook
OUTPUT_JSON = PROJECT_ROOT / 'outputs/notebook_adlm_samples.json'

# Hydra/Lightning overrides mirroring the command-line evaluation settings
OVERRIDES = [
    'mode=sample_eval',
    'loader.batch_size=1',
    'loader.eval_batch_size=1',
    'eval.perplexity_batch_size=1',
    'data=openwebtext-split',
    'model=small',
    'parameterization=subs',
    'backbone=dit',
    'model.length=1024',
    'time_conditioning=false',
    '+wandb.offline=true',
    'T=0',
    'sampling.steps=4096',
    'sampling.nucleus_p=0.9',
    'sampling.sampler=remdm-loop',
    'sampling.eta=0.02',
    'sampling.t_on=0.55',
    'sampling.t_off=0.05',
    'sampling.alpha_on=0.9',
    f'sampling.num_sample_batches={NUM_SAMPLE_BATCHES}',
    f'sampling.generated_seqs_path={OUTPUT_JSON.as_posix()}',
    f'eval.checkpoint_path={CHECKPOINT_PATH.as_posix()}',
]

# Ensure we operate from the project root so Hydra finds configs
os.chdir(PROJECT_ROOT)
os.environ.setdefault('HYDRA_FULL_ERROR', '1')
print('Working directory set to', Path.cwd())
print('Checkpoint path:', CHECKPOINT_PATH)
# Out:
# Working directory set to /hdd1/lr/discrete/ADLM
# Checkpoint path: /hdd1/lr/discrete/ADLM/ckpts/adlm-large.ckpt

# %%
import logging
from hydra import compose, initialize
from hydra.core.global_hydra import GlobalHydra
from omegaconf import OmegaConf

import dataloader
import utils
from adlm_main import _load_from_checkpoint, generate_samples

# Reset Hydra to allow multiple executions in the same notebook
GlobalHydra.instance().clear()

config_dir = PROJECT_ROOT / 'configs'
if not config_dir.is_dir():
    raise FileNotFoundError(
        f"Hydra config directory not found at {config_dir}. "
        "Run cell 2 to set PROJECT_ROOT correctly or update the path above.")

notebook_dir = PROJECT_ROOT / 'notebooks'
config_path_rel = os.path.relpath(config_dir, start=notebook_dir)
with initialize(version_base=None, config_path=config_path_rel):
    cfg = compose(config_name='config_adlm', overrides=OVERRIDES)

print('Mode:', cfg.mode)
print('Sampling batches:', cfg.sampling.num_sample_batches)
print('Checkpoint:', cfg.eval.checkpoint_path)
print('Generated sequences will be saved to:', cfg.sampling.generated_seqs_path)

# Optional: inspect a compact view of the config
display_dict = OmegaConf.to_container(cfg, resolve=True)
{k: display_dict[k] for k in ['mode', 'data', 'model', 'parameterization', 'sampling']}
# Out:
# Mode: sample_eval
# Sampling batches: 10
# Checkpoint: /hdd1/lr/discrete/ADLM/ckpts/adlm-large.ckpt
# Generated sequences will be saved to: /hdd1/lr/discrete/ADLM/outputs/notebook_adlm_samples.json
# {'mode': 'sample_eval',
#  'data': {'train': 'openwebtext-train',
#   'valid': 'openwebtext-valid',
#   'tokenizer_name_or_path': 'gpt2',
#   'cache_dir': '/hdd1/lr/data',
#   'wrap': True,
#   'streaming': False},
#  'model': {'name': 'small',
#   'type': 'ddit',
#   'hidden_size': 768,
#   'cond_dim': 128,
#   'length': 1024,
#   'n_blocks': 12,
#   'n_heads': 12,
#   'scale_by_sigma': True,
#   'dropout': 0.1,
#   'tie_word_embeddings': False},
#  'parameterization': 'subs',
#  'sampling': {'predictor': 'ddpm_cache',
#   'steps': 4096,
#   'noise_removal': True,
#   'num_sample_batches': 10,
#   'num_sample_log': 2,
#   'semi_ar': False,
#   'stride_length': 1,
#   'num_strides': 1,
#   'generated_seqs_path': '/hdd1/lr/discrete/ADLM/outputs/notebook_adlm_samples.json',
#   'nucleus_p': 0.9,
#   'eta': 0.02,
#   'sampler': 'remdm-loop',
#   't_on': 0.55,
#   't_off': 0.05,
#   'alpha_on': 0.9,
#   'dfm': False}}

# %%
# Prepare tokenizer, logger, and model
import torch
logger = logging.getLogger('adlm_inference')
if not logger.handlers:
    handler = logging.StreamHandler()
    handler.setLevel(logging.INFO)
    logger.addHandler(handler)
logger.setLevel(logging.INFO)

tokenizer = dataloader.get_tokenizer(cfg)
logger.info('Tokenizer loaded. Vocabulary size: %d', tokenizer.vocab_size)

device = 'cuda' if torch.cuda.is_available() and torch.cuda.device_count() > 0 else 'cpu'
logger.info('Using device: %s', device)

model = _load_from_checkpoint(config=cfg, tokenizer=tokenizer)
model = model.to(device)
model.eval()
logger.info('Model loaded and moved to %s', device)
# Out:
# /ssd1/LR/SW/miniconda3/envs/adlm/lib/python3.9/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Tokenizer loaded. Vocabulary size: 50257
# Using device: cuda
# Using device: cuda
# Model loaded and moved to cuda
# Model loaded and moved to cuda

# %%
# Run sampling/inference
if 'cfg' not in globals():
    raise RuntimeError("Configuration not initialized. Run cell 3 to compose the Hydra config before sampling.")
if 'logger' not in globals():
    raise RuntimeError("Logger not initialized. Run cell 4 before sampling.")
if 'tokenizer' not in globals():
    raise RuntimeError("Tokenizer not initialized. Run cell 4 before sampling.")

samples, gen_ppl, entropies = generate_samples(cfg, logger, tokenizer)

logger.info('Generated %d samples', len(samples))
logger.info('Average entropy: %.4f', sum(entropies) / max(len(entropies), 1))
logger.info('Generative perplexity: %.3f', gen_ppl)

# Preview a few sample strings
for idx, text in enumerate(samples[: min(5, len(samples))]):
    print('=' * 80)
    print(f'Sample {idx + 1}')
    print(text)

OUTPUT_JSON.parent.mkdir(parents=True, exist_ok=True)
print('Results JSON saved to:', cfg.sampling.generated_seqs_path)
# Out:
# Generating samples.
# Starting Batch  0
# 100%|██████████| 4096/4096 [01:30<00:00, 45.15it/s]
# Starting Batch  1
# 100%|██████████| 4096/4096 [01:30<00:00, 45.18it/s]
# Starting Batch  2
# 100%|██████████| 4096/4096 [01:30<00:00, 45.29it/s]
# Starting Batch  3
# 100%|██████████| 4096/4096 [01:30<00:00, 45.08it/s]
# Starting Batch  4
# 100%|██████████| 4096/4096 [01:30<00:00, 45.06it/s]
# Starting Batch  5
# 100%|██████████| 4096/4096 [01:30<00:00, 45.31it/s]
# Starting Batch  6
# 100%|██████████| 4096/4096 [01:30<00:00, 45.40it/s]
# Starting Batch  7
# 100%|██████████| 4096/4096 [01:30<00:00, 45.34it/s]
# Starting Batch  8
# 100%|██████████| 4096/4096 [01:30<00:00, 45.17it/s]
# Starting Batch  9
# 100%|██████████| 4096/4096 [01:30<00:00, 45.04it/s]
#
# Generated 10 samples
# Average entropy: 5.2350
# Generative perplexity: 15.828
# Generated 10 samples
# Average entropy: 5.2350
# Generative perplexity: 15.828
# ================================================================================
# Sample 1
# <|endoftext|> It’s smart. It’s much better than having a government, which is very monopolistic. You can find entrepreneurs who solve problems by giving different people problems. If you’re an entrepreneur, you can do all kinds of things faster than if you had a government.
#
# Do you have a vision of what a decentralized government could look like?
#
# My vision is that only a small minority of people ever want to solve a problem, and if they do, they have an overwhelming chance of being able to solve it. The problem with that is because our entire society is wasteful and the whole world is, like, a small minority of all that cares. And when a small minority tries to solve a problem, they usually get their ass kicked and aren’t able to solve it on their own.
#
# What do you think of the kind of global problems that we’re facing now before we have a decentralized government like what we have today?
#
# Who’s heard of a decentralized government? I’ve never even heard of. There are so many things in the world that are so serious, we haven’t really even touched on the system, and nature is so fucking amazing with us. But I think that a decentralized government will give us a completely different kind of government than the one we currently have.
#
# So would you be ready?
#
# I fucking hope so.
#
# Advertisements<|endoftext|>Release Date: May 25, 2016
#
# Sorry for the technical difficulties involved in this. I am going to work until I have a little of what it takes to work hard on this and make it a complete set. I am not doing this project out of a very casual attitude to these games, but just because I don't think the games are any less playing, even if the games are very fun, even if they are competitive, even if they don't quite have the mentality of a Wholesale Corp as I want to have.
#
# This set will be more of a strategy game, and not a casual game. I will be jumping in and out of games to figure out how to play a card in my deck, but the deck will also be very complex. It will allow me to stack different payouts (not just one, but two at a time) specifically for 10 random cards in my deck. I am sure that some will be used for Red and Blue decks. I don't like this game just because it's fun, I like it because I like strategy.
#
# The FAQs will be out soon. You can ask if you have questions or ideas you need to see, but if you have a new idea, or a trend or a question I don't know how to answer, feel free to post here.
#
# Also, this set will be a monthly edition. There will be 8 booster sets in each month, and I would suggest 8 of which to meet with your opponent of this series. Depending on your budget, you can only purchase 40 booster sets, unless a card is more expensive than the cost of the booster sets, plus the core set. There will be a printable edition starting then for core set cards.<|endoftext|>Roseanne star Michael M. Moore, left, Emmy Award Producers Paul Newman and Oz Sigurdson and co-star Sandra Mulligan attend the 2014 Emmy Awards with her daughters, Norman & Ashley. (Getty Images) For the third consecutive year, “Roseanne” took home the Primetime Emmy Awards, extending a winning streak that began in 2004.
#
# Viewed by more than 43 million viewers, the half-hour comedy won the category of “best female-led comedy series” for the second consecutive year, drawing more than 27 million viewers. “Roseanne” is the third comedy series to sweep the three categories, following pioneers “More Than a Night” and “30 Rock,” based on the Claudia Beckinale “1949.”
# P asked about his hopes, Cardinal Brayer also said that he wants Pope Francis to refrain from giving homosexuality advice to young Catholics. “How then can such limitations on a person’s freedom contribute to developing his or her capacity for thought? Can you teach someone how to vote and not how to think?” he said. Maybe the pope will say it now, but “he should do it for the good of humanity, for the good of culture.”
#
# Authored by Mike Ballard.
#
# Advertisements
#
# Share this: Facebook
#
# Twitter
#
# Pinterest
#
# Email
#
# WhatsApp
#
# Like this: Like Loading... Related
#
# Tags: Pope Francis, LGBT Delinquency, The New York Times.
#
# This post was originally published at God v. State.
#
# Follow Mike Ballard on Twitter: https://twitter.com/Mike_Ballard1.
#
# Advertisements<|endoftext|>(CNN) The United States will pull out of an oil pipeline agreement with Canada and Mexico if President Donald Trump does not follow through on its funding and what Donald<|endoftext|>
# ================================================================================
# Sample 3
# <|endoftext|> worried about that. But he was very much gracious, very much generous, you know? I mean, I understand that, you know, if you have to be a part with someone for five or six years, you just don’t get the content if you care. But he was very generous. He was a wonderful guy. He was a wonderful guy. So I was pleased to hear that.
#
# (Grins at him.) “I mean, I expected that. I was told that three years ago, you know? I mean, I was told that.”
#
# “So I just want to know what you think. I know that you are both a great actor and a great artist, thank you.”
#
# “I do.”
#
# (He talks in detail, then retreats to observation.)
#
# “Other than — you mentioned season one?”
#
# “It was directed by Chris Weiss,” he explained. “Chris is a dear friend of mine. And we had a lot of feedback that was there. I’m not sure what it was. Maybe it was, ‘We like the pilot. we have to do the pilot.’ Do you know what that was like?”
#
# “I do.” So, we knew that Chris was reading all of the comments. We just didn’t have the time or the amount of support to do something as simple as a feature film doing a pilot. So, it was real criticism from all the different sides.
#
# All of a sudden, we got to do a lot of things that we obviously couldn’t do. We were able to tell a radically different story where every character gets to make leaps and bounds, where Joff could have saved the kingdom. Where Jaime could have come back and he could have come with us, and that allowed us to have advantages over the network.
#
# “It’s been an absolutely wonderful experience positive project,” he said. “And we’ve gotten so much feedback. We’ve gotten massive amounts of positive feedback not on the network’s presentation of the pilot, but from the critics and the fans who’ve been very impressed with the show. There’s audiences that have grown on the show. It’s huge. It’s amazing. And when we first started, we really stumbled out of the gate and we were like, ‘Oh, okay, we need to do something else.’ And then, all of a sudden, the word started getting out.”
#
# “So, it seemed like there were some new voices, and obviously, there’s a lot of opinions on the show online.”
#
# “I agree,” he said. “And though, I’d like to say that the critics are also people that we’ve heard a lot from. Going forward, we get so much feedback, that it makes sense for us to be listening to that. It seems like it works that way though. I’m really excited about that. I’m also excited, you know, about now having a second season.”
#
# You mentioned that you felt like maybe you should move on from season one, and I know there’s been a lot of pushback. What’s the transition been like? Do you think it is going away?
#
# “Yeah, no, I wouldn’t say “think it is going away.” It’s just been a wonderful transition as an actor and a writer.”
#
# It was weird. Like — it was totally weird, you know? But it was kind of crazy, you know? It was kind of like when we did thinking a second season of Game of Thrones was a crazy idea.
#
# “No, it’s been one of those things, where you’re the only one who’s not looking and thinking, ‘What are we going to do all over again? Let’s see what season one is like and away we go.’ And maybe you’re going to get better in your chair when the reviews start to come out. But, again, you know, it’s just been a wonderful transition. And the feedback from a lot of the critics and the fans. The Atmospheres have just been really good really. And I just really poured all of my energy into it. The feedback has been tremendous. There’s no way to say, ‘Oh, we can just wrap up.’ It has been wonderful. It’s been incredibly supportive. The feedback has been really, really good.’”
#
# “Exactly.”
#
