# %% [markdown]
# ## Anchored Diffusion Inference Notebook
# Use this notebook to load a trained ADLM checkpoint and generate text samples or compute evaluation metrics on a few samples
#
# ### Prerequisites
# - The working directory is set to the repository root.
# - A trained checkpoint is available on disk.
#
# Adjust the parameters in the next cell to point to your checkpoint and sampling configuration.

# %%
from pathlib import Path
import os

# --- User configuration ----------------------------------------------------
PROJECT_ROOT = Path('/hdd1/lr/discrete/remdm')  # Update if running elsewhere
CHECKPOINT_PATH = PROJECT_ROOT / 'ckpts/adlm-large.ckpt'
# Supported checkpoints: adlm-medium.ckpt (262B tokens), adlm-large.ckpt (524B tokens)
NUM_SAMPLE_BATCHES = 10  # Number of batches to sample in this notebook
OUTPUT_JSON = PROJECT_ROOT / 'outputs/notebook_adlm_samples.json'

# Hydra/Lightning overrides mirroring the command-line evaluation settings
OVERRIDES = [
    'mode=sample_eval',
    'loader.batch_size=1',
    'loader.eval_batch_size=1',
    'eval.perplexity_batch_size=1',
    'data=openwebtext-split',
    'model=small',
    'parameterization=subs',
    'backbone=dit',
    'model.length=1024',
    'time_conditioning=false',
    '+wandb.offline=true',
    'T=0',
    'sampling.steps=4096',
    'sampling.nucleus_p=0.9',
    'sampling.sampler=remdm-loop',
    'sampling.eta=0.02',
    'sampling.t_on=0.55',
    'sampling.t_off=0.05',
    'sampling.alpha_on=0.9',
    f'sampling.num_sample_batches={NUM_SAMPLE_BATCHES}',
    f'sampling.generated_seqs_path={OUTPUT_JSON.as_posix()}',
    f'eval.checkpoint_path={CHECKPOINT_PATH.as_posix()}',
]

# Ensure we operate from the project root so Hydra finds configs
os.chdir(PROJECT_ROOT)
os.environ.setdefault('HYDRA_FULL_ERROR', '1')
print('Working directory set to', Path.cwd())
print('Checkpoint path:', CHECKPOINT_PATH)
# Out:
# Working directory set to /hdd1/lr/discrete/remdm
# Checkpoint path: /hdd1/lr/discrete/remdm/ckpts/adlm-large.ckpt

# %%
import logging
from hydra import compose, initialize
from hydra.core.global_hydra import GlobalHydra
from omegaconf import OmegaConf

import dataloader
import utils
from adlm_main import _load_from_checkpoint, generate_samples

# Reset Hydra to allow multiple executions in the same notebook
GlobalHydra.instance().clear()

config_dir = PROJECT_ROOT / 'configs'
if not config_dir.is_dir():
    raise FileNotFoundError(
        f"Hydra config directory not found at {config_dir}. "
        "Run cell 2 to set PROJECT_ROOT correctly or update the path above.")

notebook_dir = PROJECT_ROOT / 'notebooks'
config_path_rel = os.path.relpath(config_dir, start=notebook_dir)
with initialize(version_base=None, config_path=config_path_rel):
    cfg = compose(config_name='config_adlm', overrides=OVERRIDES)

print('Mode:', cfg.mode)
print('Sampling batches:', cfg.sampling.num_sample_batches)
print('Checkpoint:', cfg.eval.checkpoint_path)
print('Generated sequences will be saved to:', cfg.sampling.generated_seqs_path)

# Optional: inspect a compact view of the config
display_dict = OmegaConf.to_container(cfg, resolve=True)
{k: display_dict[k] for k in ['mode', 'data', 'model', 'parameterization', 'sampling']}
# Out:
# Mode: sample_eval
# Sampling batches: 10
# Checkpoint: /hdd1/lr/discrete/remdm/ckpts/adlm-large.ckpt
# Generated sequences will be saved to: /hdd1/lr/discrete/remdm/outputs/notebook_adlm_samples.json
# {'mode': 'sample_eval',
#  'data': {'train': 'openwebtext-train',
#   'valid': 'openwebtext-valid',
#   'tokenizer_name_or_path': 'gpt2',
#   'cache_dir': '/hdd1/lr/data',
#   'wrap': True,
#   'streaming': False},
#  'model': {'name': 'small',
#   'type': 'ddit',
#   'hidden_size': 768,
#   'cond_dim': 128,
#   'length': 1024,
#   'n_blocks': 12,
#   'n_heads': 12,
#   'scale_by_sigma': True,
#   'dropout': 0.1,
#   'tie_word_embeddings': False},
#  'parameterization': 'subs',
#  'sampling': {'predictor': 'ddpm_cache',
#   'steps': 4096,
#   'noise_removal': True,
#   'num_sample_batches': 10,
#   'num_sample_log': 2,
#   'semi_ar': False,
#   'stride_length': 1,
#   'num_strides': 1,
#   'generated_seqs_path': '/hdd1/lr/discrete/remdm/outputs/notebook_adlm_samples.json',
#   'nucleus_p': 0.9,
#   'eta': 0.02,
#   'sampler': 'remdm-loop',
#   't_on': 0.55,
#   't_off': 0.05,
#   'alpha_on': 0.9,
#   'dfm': False}}

# %%
# Prepare tokenizer, logger, and model
import torch
logger = logging.getLogger('adlm_inference')
if not logger.handlers:
    handler = logging.StreamHandler()
    handler.setLevel(logging.INFO)
    logger.addHandler(handler)
logger.setLevel(logging.INFO)

tokenizer = dataloader.get_tokenizer(cfg)
logger.info('Tokenizer loaded. Vocabulary size: %d', tokenizer.vocab_size)

device = 'cuda' if torch.cuda.is_available() and torch.cuda.device_count() > 0 else 'cpu'
logger.info('Using device: %s', device)

model = _load_from_checkpoint(config=cfg, tokenizer=tokenizer)
model = model.to(device)
model.eval()
logger.info('Model loaded and moved to %s', device)
# Out:
# /ssd1/LR/SW/miniconda3/envs/adlm/lib/python3.9/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Tokenizer loaded. Vocabulary size: 50257
# Using device: cuda
# Tokenizer loaded. Vocabulary size: 50257
# Using device: cuda
# Model loaded and moved to cuda
# Model loaded and moved to cuda

# %%
# Run sampling/inference
if 'cfg' not in globals():
    raise RuntimeError("Configuration not initialized. Run cell 3 to compose the Hydra config before sampling.")
if 'logger' not in globals():
    raise RuntimeError("Logger not initialized. Run cell 4 before sampling.")
if 'tokenizer' not in globals():
    raise RuntimeError("Tokenizer not initialized. Run cell 4 before sampling.")

samples, gen_ppl, entropies = generate_samples(cfg, logger, tokenizer)

logger.info('Generated %d samples', len(samples))
logger.info('Average entropy: %.4f', sum(entropies) / max(len(entropies), 1))
logger.info('Generative perplexity: %.3f', gen_ppl)

# Preview a few sample strings
for idx, text in enumerate(samples[: min(5, len(samples))]):
    print('=' * 80)
    print(f'Sample {idx + 1}')
    print(text)

OUTPUT_JSON.parent.mkdir(parents=True, exist_ok=True)
print('Results JSON saved to:', cfg.sampling.generated_seqs_path)
# Out:
# Generating samples.
# Starting Batch  0
# 100%|██████████| 4096/4096 [01:14<00:00, 54.62it/s]
# Starting Batch  1
# 100%|██████████| 4096/4096 [01:14<00:00, 54.68it/s]
# Starting Batch  2
# 100%|██████████| 4096/4096 [01:14<00:00, 54.77it/s]
# Starting Batch  3
# 100%|██████████| 4096/4096 [01:14<00:00, 54.95it/s]
# Starting Batch  4
# 100%|██████████| 4096/4096 [01:15<00:00, 54.54it/s]
# Starting Batch  5
# 100%|██████████| 4096/4096 [01:14<00:00, 55.04it/s]
# Starting Batch  6
# 100%|██████████| 4096/4096 [01:14<00:00, 55.21it/s]
# Starting Batch  7
# 100%|██████████| 4096/4096 [01:14<00:00, 54.96it/s]
# Starting Batch  8
# 100%|██████████| 4096/4096 [01:15<00:00, 54.12it/s]
# Starting Batch  9
# 100%|██████████| 4096/4096 [01:14<00:00, 54.71it/s]
#
# Generated 10 samples
# Average entropy: 5.2613
# Generative perplexity: 17.095
# Generated 10 samples
# Average entropy: 5.2613
# Generative perplexity: 17.095
# ================================================================================
# Sample 1
# <|endoftext|> cost," Trump told CNBC. "But the problem is we need the money, and if we cannot make the money, then it’s not that expensive."
#
# Trump won't tell me his wall" will cost up to 9%. Study of 3 policy budgets says opposite. — Ashley Smith (@_AshleySmith) June 18, 2016
#
# _____________________________________________________________________________
#
# According to one expert, the wall will probably cost $12 billion, but according to another expert, the cost will be far higher than Trump's estimate by at least $20 billion.
#
# So why is Trump always saying such a number? It’s not because he’s lying. On the contrary, he can’t really tell us much at all.
#
# June 16, 2016
#
# Trump has touted his support for a wall to stop the flow of illegal immigrants entering the country, but hasn’t yet offered to reveal the details of its size. John Raoux/Reuters
#
# In an interview with CNBC prior to Trump’s call for a border wall, he explained, in one of his favorite lines, the problem of illegal immigrants entering the U.S.: “The problem is, we have, of course, Mexico has the drugs, they have the guns, and they have the people, and therefore we have a lot of illegal who are coming out of control.”
#
# He continued:
#
# The problem is, it’s a problem, a problem that we’re not going to solve without the out-of-control people that are coming in. And so we’ve got to do something.
#
# I can’t yet reveal what I would say in private, but I know I have some fantastic ideas, and one of them is a beautiful, wonderful border wall that you are going to see—you hear me talking about the size of the wall, the concrete and the steel and the all-steel wall, and you see how big the wall is.
#
# June 18, 2016
#
# ___
#
# The Republican nominee says that building a wall will help make the country safer. Win McNamee/Getty
#
# During the second presidential debate, Trump responded to a question about the problem of illegal immigrants by laying out his support for a border wall, which he said would reduce crime and violence on the border:
#
# First of all, I’ll tell you, and I totally understand the problem that we’re having. You know, the gangsters tell you that the problem we’re having comes from illegal immigration, and that’s absolutely true. The fact is that a hundred years ago, people that crossed the border bought guns, and bought drugs, and that’s a big problem because they kind of knew that drugs were being used here.
#
# But the problem is—I mean, I don’t want to mince words, we have to solve it. We have to have a wall. A wall is not going to be put up by anybody, because it cannot be put up by anybody. And every little gang, every little criminal gang that has crossed the border, they go down and go, “Oh we’re not very good,” and they flee over to Mexico, and they go down and we have a problem and we have a problem.
#
# But we have a situation where the problem is, the problem is going to get worse, and so we have to continue to solve the problem, and the solution right now is a great wall, and I promise you we’ll be spending a lot of money on it.
#
# A concrete wall on the southern U.S. border may cost you lot, but Trump believes it can stop the flood of Syrian refugees. Why not? He says it can’t, and here’s why:
#
# Throughout the debate, Trump has tried to push the fine point, and he's failed. U.S. Homeland Security Janet Napolitano did talk about the wall during Thursday’s debate, but it’s just a debate, and it seems unlikely that Trump is able to repeat a promise made during the first debate.<|endoftext|>To stop the growth of national debt, the US must use eight –out of 10 houses the nation has– in time to pay off all of the United States’ outstanding national debt over the next decade, congressional Democrats said today.
#
# The Democratic National Committee introduced legislation outlining an across-the-board plan to accomplish this, known as Rebuild Team 101. If passed in full, the plan would eventually pay off all of the nation’s outstanding debt and lower the debt to the deficit ratio over the next decade.
#
# Central to suspicion were "mehandling" in that it was possible for suspects to take cover. Villagers who did not want to cooperate with the FBI could be murdered or coerced into being a ringleader, framed, or be "dquered" in some mode (the victims were eight to twelve).
#
# <|endoftext|>
# ================================================================================
# Sample 4
# <|endoftext|> not going to have to defend the place.<|endoftext|>The iPhone 5 is a device that looks like a Macbook, and resembles any other smartphone, but it's not built on specs laid out by Apple founder Steve Jobs. It runs all of the same hardware and software apps as Cook reveals, and you can use it to visit other people and share photos and content.
#
# Apple CEO Tim Cook has worked with developers to build great apps for the iPhone, a point he made about the iPhone 5 at Apple's WWDC. But a number of developers have written apps that won't access an Apple browser like Safari, and Apple has been worried to get that past.
#
# On Tuesday, Apple announced plans to support developers working on smartphones. Samsung, LG, and Huawei are major players in the Chinese market, and they're offering Apple's help for the future.
#
# "If Samsung and LG are going to get big in the market, as we hope, they will not only be an OEM leader, but a software leader," Cook told WWDC. "I think they're looking at the Chinese market. And we do. And we think they can build better phones with better technology, and we will be there to help them do it with our hardware, support, and software."
#
# Apple also recently announced partnerships with Nokia, including early interest and investments in undisclosed amounts. The company wants to get Nokia's Android smartphones in China, stating: "Nokia's award-winning smartphones, such as the Nokia 6, reach not just tens of millions, but hundreds of millions, in China."
#
# Huawei started with Samsung, but is by far the biggest player in the Chinese market. According to research firm Bradley Horowitz, Huawei owns a 36 percent share of the Chinese smartphone market, and Lenovo owns 35 percent of all Chinese smartphones, respectively. Google's plan to get into the Chinese market has gotten some mixed reviews. Google released two Nexus phones in 2013: the Nexus 7 and the Nexus 6P.
#
# In 2012, Google decided to move into the Chinese market first, but it seemed to be a one-time strategy. A lot of apps for Chinese phones have been written but no real phones or tablets have appeared in the market.<|endoftext|>NEW YORK (AP) — Dave Grohl, one of Pearl Jam’s original drummers back in the 1990s, is coming to show again in June, as is Pearl Jam drummer Phil Kenos.
#
# Pearl Jam has canceled all of its spring and summer concerts in New York’s Barclays Center but still plans to play there again in June to promote their new album, released Friday. There’s also a charity concert featuring Kenos that is now on sale online. Tickets are available for $30, and car registration $10. The concert also includes a free digital download of the new studio album.
#
# Without a specific date for releasing the band’s newest album this fall, Kenos said the band does plan to tour together again in the fall.
#
# “We’re going to come back and remain on the road for four or five days,” he said.
#
# The album is available on iTunes as a download. Live performances by Pearl Jam’s band members are also available on iTunes. Performances by Grohl, James Moore, Eddie Erb, Tom Petty, Jake Gould, Jeff Beck, Timmins and Jeff Lynne are also available.
#
# Tickets are on sale now at Barclays Center. The concert is $35 and includes a free digital download of the 11th album, which includes songs such as “I Love The Wind,” “Freedom” and “Town Is Burning.” All of the concerts will be free.
#
# “The club really embraced us,” Kenos said. “And now, because we’re out of our spring and summer shows, the organization has really embraced us.”
#
# In an interview last Friday, Kenos and bassist Tim Matheson said they had a strong personal connection to the music of the era and the rock movement in general.
#
# “It’s really part of the DNA of who we are,” he said. “We all have a connection to that music. Some of the recorded music that we write goes back to that era. It kind of represents who we are.”
#
# Kenos was also bassist and guitarist in the cover bands Phoebe Lowell, Anthony Molinaro, and A.J. Simpson.
#
# After forming his first rock band, Maroon 5, in 1997, Kenos toured with a few producers — performing in some local house band shows and at such places as Gotye Nye Hall and Chameleon Hall, where he studied as a drummer, guitarist and songwriter.
#
# “I did a lot of fun things, and then I just went, ‘I just want to go back and make<|endoftext|>
# ================================================================================
# Sample 5
# <|endoftext|> 50,000 rides in the first five days," said TTC chair Kevin O'Connor. "Our bus fleet has experienced its largest increase in 16 years, and the percentage of people taking streetcars to downtown work is continuing to increase. We will continue to grow our bus fleet to serve more riders as more buses are leased."
#
# The report also calls for 200 streetcars to operate in the coming years, which the TTC says means riders will better know the schedule.
#
# The staff report backs the expansion, and notes that it is all part of the TTC's ridership plan. It says the network delivers 260,000 riders per hour during weekday rush hours and peak times, when ridership is low and real times are crucial. The reality is that the streetcar extension will carry about 200 buses per hour, which could mean fewer riders during peak hours. When the ridership extension in the first half of 2016 began service, the average was 105,000 riders at peak times, but dropped to 89,000 as service was introduced.
#
# Staff also said the the expansion would not have been possible during the Rob Ford era. But less than nine months after re-election, staff poured millions of dollars into a build-to-market strategy, a new Etobicoke Centre and an expansion of the relief line.
#
# "Providing transit service during rush hours is a viable and consistent strategy to support key transit improvements while also delaying other projects," says the staff report. "It will provide more dependable, reliable service while increasing ridership to residents. We are confident this plan will deliver significant savings to both staff and taxpayers."
#
# Monday's meeting saw most councillors support the extension by a comfortable margin. Six Liberals voted for the extension, while only two Conservatives voted against.
#
# Councillor Charles Panetta questioned why the extension was needed, but urged the city to "make simple adjustments" to cut the cost. He said the council should spell out the extension's purpose, rather than want it to be as long-term.<|endoftext|>The life of new college graduates can be difficult, says Andrew Alpert who teaches at the University of Florida and is an adviser for U.S. Conference of Mayors (which also represents Massachusetts).
#
# "And that can be even more challenging for students in general. It's become a stereotype that students today are ill-prepared for the workforce. And I think that will be a trend over time."
#
# More college students are becoming aware that the degrees they've gotten affect them more than the amount of pay they've earned since completing their education. Without them, the mental burden and stress on college students are going to continue to grow in the long run.
#
# 1. A student's education does not impact their ability to get a job because the job market experience they need to get isn't directly related to their training.
#
# Students' college schooling isn't tied to their experience in the job market, so there's no way it makes college graduates unemployable. And in fact, there's no way they'll never get the best job that they can get. In an era of stagnant labor wages, many students are taking lower-paying jobs and they're more likely to drop out of school because their degrees isn't relevant to better-paying jobs.
#
# The real takeaway for employers, though, is that it's important that students stay in the job market so that they can gain some knowledge, acquire some skills to acclimate those skills, and gain some experience to help them ultimately get the kind of job they want.
#
# 2. Money is a problem
#
# When students go to college, it's training that helps them get the best job that they can get, otherwise they don't have money. In the last 50 years, professors have said that demand for their courses and that money make a difference in the life of those who take them. In fact, roughly 40 percent of college students are unemployed before they have enough money for their post-secondary education.
#
# It's a hell of a lot worse to not have enough money. Of course, there are students who spend too much money for their degrees, and universities and colleges shouldn't impose money limits on these students; they should just say yes to support as well as tuition.
#
# Moreover, not all of students' education requirements are specific to what they practice. If you teach one skill rather than a combination of skills, you should understand that students aren't likely to want that combination of specialized skills to eventually get a good job.
#
# "If you teach multiple skills, they're probably going to come up with a better value," says Alpert, who has extensively studied this issue. "But if you're teaching one skill rather than a combination of skills, they won't want to try."
#
# 3. Experience is a barrier
#
# Learning and experience are valuable things, but there is one big barrier to learning enough skills to get into the job market: Getting experience to combine that skill. It's up to<|endoftext|>
# Results JSON saved to: /hdd1/lr/discrete/remdm/outputs/notebook_adlm_samples.json
